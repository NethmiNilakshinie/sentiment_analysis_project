# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle (5).json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'nilakshisenevirathne', 'key': 'eac7b59469c73ee6aa96e64ac06b9b28'}

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (1.8.3)
# Requirement already satisfied: black>=24.10.0 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (0.1.14)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: packaging in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (25.0)
# Requirement already satisfied: protobuf in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: six>=1.10 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (4.5.0)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: colorama in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.5)
# Requirement already satisfied: webencodings in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from requests->kaggle) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nethmi\appdata\local\programs\python\python313\lib\site-packages (from requests->kaggle) (2025.10.5)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip','r') as zip_ref:
    zip_ref.extractall('../artifacts')
